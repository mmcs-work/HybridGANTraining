# %%
# !python train.py  --dataset 'cifar' --batch 64 --epochs 52  --img_size 32  --logdir './glow_cifar.log' --path_sample "./sample_cifar" --path_model "./checkpoint_cifar"
# Out:
# Namespace(affine=False, batch=64, dataset='cifar', epochs=52, img_size=32, logdir='./glow_cifar.log', lr=0.0001, n_bits=5, n_block=4, n_flow=32, n_sample=20, no_lu=False, path_model='./checkpoint_cifar', path_sample='./sample_cifar', temp=0.7)
# Files already downloaded and verified
# 100%|█| 625/625 [09:35<00:00,  1.09it/s, logP=-1.718, logdet=4.566, lr=0.000100,
# 100%|█| 157/157 [00:45<00:00,  3.49it/s, logP=-1.769, logdet=4.567, lr=0.000100,
# 100%|█| 625/625 [09:37<00:00,  1.08it/s, logP=-1.797, logdet=4.792, lr=0.000100,
# 100%|█| 157/157 [00:45<00:00,  3.48it/s, logP=-1.879, logdet=4.793, lr=0.000100,
# 100%|█| 625/625 [09:37<00:00,  1.08it/s, logP=-1.947, logdet=4.980, lr=0.000100,
# 100%|█| 157/157 [00:45<00:00,  3.47it/s, logP=-1.889, logdet=4.981, lr=0.000100,
# 100%|█| 625/625 [09:38<00:00,  1.08it/s, logP=-2.120, logdet=5.162, lr=0.000100,
# 100%|█| 157/157 [00:45<00:00,  3.48it/s, logP=-2.124, logdet=5.162, lr=0.000100,
# ...
