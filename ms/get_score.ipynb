# %%
# !python mnist_score.py --input_image_dir '/nfs/students/winter-term-2020/project-5/project-5/flow_gan/separate_img'  --batch_size 64
# Out:
# PACKAGES LOADED
# /nfs/students/winter-term-2020/project-5/project-5/flow_gan/separate_img
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# load model successfully
# .torch.Size([64, 1, 28, 28])
#
# Inception mean:  4.154783997387414
# Inception std:  0.7569350259095914

# %%
# !python mnist_score.py # --input_image_dir '/nfs/students/winter-term-2020/project-5/project-5/flow_gan/separate_img'  --batch_size 64
# Out:
# PACKAGES LOADED
# ./data//crops/
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# ...
